# %%
import numpy as np
import scipy.io
from grid import grid
import torchkbnufft as tkbn
import torch
import utils_dist
import matplotlib.pyplot as plt

k_radial = scipy.io.loadmat('radial_data.mat')['k']

'''
nRO: the number of readout points
nSpocks: the number of kdata trajectories.
'''
nRO, nSpokes = k_radial.shape

# %% [markdown]
# # 1. Radial Sampling pattern

# %%
PI = np.pi
GA = 111.246117975 * (PI/180)
'Normalize spoke length from -.5 to .5 cause of gridding func'
r = np.linspace(-0.5, 0.5, nRO).reshape((nRO,1))  # K-space trajectory
print(r.shape)

theta = np.mod(np.arange(PI/2, nSpokes * GA, GA), 2*PI)
print(theta.min(), theta.max(), theta.shape)

traj = r * np.exp(1j*theta)
print(traj.shape)

ns = 20
plt.plot(traj[:,:ns].real, traj[:,:ns].imag)
plt.show()
# Out:
# (384, 1)
# 0.010908202668886702 6.2745803238948525 (600,)
# (384, 600)

# %% [markdown]
# # ....... Do the spokes match Nyquist rate? ........

# %% [markdown]
# # 2. Basic gridding reconstruction

# %%
k_cartesian = grid(k_radial, k=traj, n=nRO)
print(k_cartesian.shape)

k_cart_recon = utils_dist.ifft2c(k_cartesian)
utils_dist.imshow1row([k_cartesian], ["k-space"],  isMag=True, norm=0.1)
utils_dist.imshow1row([abs(k_cart_recon)], ["Image"], isMag=False) # But blurry cause of additional projections acquired over full rotation
utils_dist.imshow1row([k_radial, k_cartesian], isMag=True, norm=0.1)
# Out:
# (384, 384)

# %% [markdown]
# # 3. Compensate density using ramp

# %%
def get_ramp(k_radial):
    nRO , nSpocks = k_radial.shape
    ramp = np.abs(np.linspace(-1 + 1/nSpocks, 1-1/nSpocks, nRO))[:, None] + 1/nSpocks
    return ramp

ramp = get_ramp(k_radial)
k_radial_ramp = ramp * k_radial
k_cart_ramp = grid(k_radial_ramp, traj, nRO)
k_cart_ramp_recon = utils_dist.ifft2c(k_cart_ramp)
utils_dist.imshow1row([abs(k_cart_ramp_recon), abs(k_cart_recon)],['Ramp filtered', 'Original'],isMag=False)

# %% [markdown]
#  # 4. Oversampling

# %%
os_rate = 2
k_cart_ramp_os = grid(k_radial_ramp, traj, nRO*os_rate)
k_cart_ramp_os_recon = utils_dist.ifft2c(k_cart_ramp_os)
k_cart_ramp_os_recon_cropped = utils_dist.crop(k_cart_ramp_os_recon, nRO*os_rate, os_rate) 
utils_dist.imshow1row([abs(k_cart_ramp_os_recon_cropped),abs(k_cart_ramp_recon), abs(k_cart_recon)],['over sampled','Ramp filtered', 'Original'],isMag=False)

# %% [markdown]
# # 5. Deapodize (divide same kernel) as siganls pf intensity higher in center due to regridding kernel shape

# %%
delta = np.zeros_like(k_radial)
delta[nRO//2, :] = 1
utils_dist.imshow1row([delta])

# %%
tri_k = grid(delta, traj, nRO*os_rate)
c = utils_dist.ifft2c(tri_k)
a = 1

# %%
k_cart_ramp_os_deapo_recon = k_cart_ramp_os_recon /(c + a)
k_cart_ramp_os_deapo_recon_cropped = utils_dist.crop(k_cart_ramp_os_deapo_recon, nRO*os_rate, os_rate)
utils_dist.imshow1row([abs(k_cart_ramp_os_deapo_recon_cropped),abs(k_cart_ramp_os_recon_cropped),abs(k_cart_ramp_recon), abs(k_cart_recon)],['deapodized','over sampled','Ramp filtered', 'Original'],isMag=False)
